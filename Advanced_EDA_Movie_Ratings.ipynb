# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\User\Downloads\Movie-Rating.csv')

# %%
movies.size
# Out:
# 3354

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.shape
# Out:
# (559, 6)

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillions', 'Year']
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head(2)
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008

# %%
movies.describe() #Descriptive statistics for numerical columns
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.describe().transpose() #Descriptive statistics for numerical columns with transposed format
# Out:
#                  count         mean        std     min     25%     50%  \
# CriticRatings    559.0    47.309481  26.413091     0.0    25.0    46.0
# AudienceRatings  559.0    58.744186  16.826887     0.0    47.0    58.0
# BudgetMillions   559.0    50.236136  48.731817     0.0    20.0    35.0
# Year             559.0  2009.152057   1.362632  2007.0  2008.0  2009.0
#
#                     75%     max
# CriticRatings      70.0    97.0
# AudienceRatings    72.0    96.0
# BudgetMillions     65.0   300.0
# Year             2010.0  2011.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.describe() #Descriptive statistics for all columns
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='hex')
plt.show()

# %%
j1= sns.jointplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='scatter')
plt.show()

# %%
j2= sns.jointplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='reg')
plt.show()

# %%
j3= sns.kdeplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='kde')
plt.show()

# %%
j4= sns.jointplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='hist')
plt.show()

# %%
j4= sns.jointplot(x='CriticRatings', y='AudienceRatings', data=movies, kind='resid')
plt.show()

# %%
m1= sns.displot(movies, x='CriticRatings', kde=True)
plt.show()

# %%
m1= sns.distplot(movies['CriticRatings'], kde=True)
plt.show()

# %%
sns.set_style('whitegrid')
m1= sns.displot(movies, x='CriticRatings', kde=True)
plt.show()

# %%
visl1= sns.displot(movies, x='AudienceRatings', kde=True)
plt.show()

# %%
visl2 = sns.lmplot(x='CriticRatings', y='AudienceRatings', data=movies)

# %%
visl3= sns.lmplot(x='CriticRatings', y='AudienceRatings', data=movies, hue='Genre', palette='Set1', markers=['o', 'v', 's', 'D', 'p', 'X'], scatter_kws={'s':100})  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 visl3= sns.lmplot(x='CriticRatings', y='AudienceRatings', data=movies, hue='Genre', palette='Set1', markers=['o', 'v', 's', 'D', 'p', 'X'], scatter_kws={'s':100})
#       2 plt.show()
#
# File c:\Users\User\anaconda3\Lib\site-packages\seaborn\regression.py:631, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     629     markers = [markers] * n_markers
#     630 if len(markers) != n_markers:
# --> 631     raise ValueError("markers must be a singleton or a list of markers "
# ...

# %%
visl4= sns.boxplot(x='Genre', y='AudienceRatings', data=movies)

# %%
visl5= sns.violinplot(x='Genre', y='AudienceRatings', data=movies)
