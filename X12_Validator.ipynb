# %%
pip install x12-edi-tools
# Out:
# Collecting x12-edi-tools
#   Downloading x12_edi_tools-0.1.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: requests>=2.25.1 in c:\users\user\anaconda3\lib\site-packages (from x12-edi-tools) (2.32.3)
# Requirement already satisfied: cryptography>=3.4.7 in c:\users\user\anaconda3\lib\site-packages (from x12-edi-tools) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\anaconda3\lib\site-packages (from cryptography>=3.4.7->x12-edi-tools) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.7->x12-edi-tools) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.25.1->x12-edi-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.25.1->x12-edi-tools) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.25.1->x12-edi-tools) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.25.1->x12-edi-tools) (2025.10.5)
# Downloading x12_edi_tools-0.1.2-py3-none-any.whl (29 kB)
# Installing collected packages: x12-edi-tools
# Successfully installed x12-edi-tools-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from x12_edi_tools.x_12_validator import X12Validator

# %%
validator = X12Validator()
errors= validator.validate("C:\\Users\\User\\Downloads\\Sample_837.edi")
print("Validation errors:", errors)
# Out:
# Validation errors: (False, ['Missing required segment: ISA', 'Missing required segment: GS', 'Missing required segment: ST', 'Missing required segment: SE', 'Missing required segment: GE', 'Missing required segment: IEA', 'X12 document must start with ISA and end with IEA', 'Invalid ISA segment', 'Invalid GS segment', 'Invalid ST segment', 'Invalid SE segment', 'Invalid GE segment', 'Invalid IEA segment'], [])
